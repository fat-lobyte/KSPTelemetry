# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
telemetry_file = r"YourPathToKSPHERE\GameData\Telemetry/Telemetry.csv"

# %%
data = pd.read_csv(telemetry_file, sep='\t', index_col=0)
data.fillna(method="ffill", inplace=True) # fill everything we can with the previous value

# %%
# show all channels
data.plot(subplots=True, title="Telemetry");
# Out:
# <img src="data:image/png;base64,..." width="852">

# %%
# plot one channel vs another
data.plot(x="altitude", y="static_pressure", title="Pressure vs Altitude");
# Out:
# <img src="data:image/png;base64,..." width="640">
